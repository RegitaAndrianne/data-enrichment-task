# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import json
import requests

# %% [markdown]
# ## Import Football data

# %%
fb = pd.read_csv('football.csv')
fb
# Out:
#                    name
# 0            Chelsea FC
# 1            Arsenal FC
# 2            Everton FC
# 3  Manchester United FC
# 4    Manchester City FC
# 5        Aston Villa FC
# 6             Fulham FC
# 7          Liverpool FC
# 8        Southampton FC
# 9  Tottenham Hotspur FC

# %% [markdown]
# ## Import API from RapidAPI

# %%
import requests

url = "https://premier-league-standings1.p.rapidapi.com/"

headers = {
	"X-RapidAPI-Key": "ed3284ad15msh9c0872c017bc266p139ab2jsn355a61eec44a",
	"X-RapidAPI-Host": "premier-league-standings1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

# %%
data = response.json()

# %%
df = pd.json_normalize(data)
df
# Out:
#                   team.name  \
# 0                   Arsenal
# 1           Manchester City
# 2         Tottenham Hotspur
# 3          Newcastle United
# 4                   Chelsea
# 5         Manchester United
# 6                    Fulham
# 7                 Liverpool
# 8    Brighton & Hove Albion
# 9           West Ham United
# 10                Brentford
# 11                  Everton
# 12           Crystal Palace
# 13          AFC Bournemouth
# 14              Aston Villa
# 15              Southampton
# 16           Leicester City
# 17             Leeds United
# 18  Wolverhampton Wanderers
# 19        Nottingham Forest
#
#                                             team.logo team.abbreviation  \
# 0   https://a.espncdn.com/i/teamlogos/soccer/500/3...               ARS
# 1   https://a.espncdn.com/i/teamlogos/soccer/500/3...               MNC
# 2   https://a.espncdn.com/i/teamlogos/soccer/500/3...               TOT
# ...

# %% [markdown]
# ## Adding 'FC' to team.name

# %%
df['team.name'] = df['team.name'].apply(lambda x: x + ' '+'FC')

# %%
df
# Out:
#                      team.name  \
# 0                   Arsenal FC
# 1           Manchester City FC
# 2         Tottenham Hotspur FC
# 3          Newcastle United FC
# 4                   Chelsea FC
# 5         Manchester United FC
# 6                    Fulham FC
# 7                 Liverpool FC
# 8    Brighton & Hove Albion FC
# 9           West Ham United FC
# 10                Brentford FC
# 11                  Everton FC
# 12           Crystal Palace FC
# 13          AFC Bournemouth FC
# 14              Aston Villa FC
# 15              Southampton FC
# 16           Leicester City FC
# 17             Leeds United FC
# 18  Wolverhampton Wanderers FC
# 19        Nottingham Forest FC
#
#                                             team.logo team.abbreviation  \
# 0   https://a.espncdn.com/i/teamlogos/soccer/500/3...               ARS
# 1   https://a.espncdn.com/i/teamlogos/soccer/500/3...               MNC
# 2   https://a.espncdn.com/i/teamlogos/soccer/500/3...               TOT
# ...

# %% [markdown]
# ## Filtering team Name

# %%
teamFilter = fb['name'].to_list()
teamFilter
# Out:
# ['Chelsea FC',
#  'Arsenal FC',
#  'Everton FC',
#  'Manchester United FC',
#  'Manchester City FC',
#  'Aston Villa FC',
#  'Fulham FC',
#  'Liverpool FC',
#  'Southampton FC',
#  'Tottenham Hotspur FC']

# %% [markdown]
# ## Filter the Data to match the original data

# %%
df['team.name'].isin(teamFilter)
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4      True
# 5      True
# 6      True
# 7      True
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# Name: team.name, dtype: bool

# %% [markdown]
# ## Filter the data and reset the index

# %%
df = df[df['team.name'].isin(teamFilter)].reset_index(drop=True)

# %%
df
# Out:
#               team.name                                          team.logo  \
# 0            Arsenal FC  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 1    Manchester City FC  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 2  Tottenham Hotspur FC  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 3            Chelsea FC  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 4  Manchester United FC  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 5             Fulham FC  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 6          Liverpool FC  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 7            Everton FC  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 8        Aston Villa FC  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 9        Southampton FC  https://a.espncdn.com/i/teamlogos/soccer/500/3...
#
#   team.abbreviation  stats.wins  stats.losses  stats.ties  stats.gamesPlayed  \
# ...

# %% [markdown]
# ## Export to CSV

# %%
df.to_csv('footballAPIClean.csv', encoding='utf-8', index=False)

# %%
fb_new = pd.read_csv('footballAPIClean.csv')
fb_new
# Out:
#               team.name                                          team.logo  \
# 0            Arsenal FC  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 1    Manchester City FC  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 2  Tottenham Hotspur FC  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 3            Chelsea FC  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 4  Manchester United FC  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 5             Fulham FC  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 6          Liverpool FC  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 7            Everton FC  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 8        Aston Villa FC  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 9        Southampton FC  https://a.espncdn.com/i/teamlogos/soccer/500/3...
#
#   team.abbreviation  stats.wins  stats.losses  stats.ties  stats.gamesPlayed  \
# ...
